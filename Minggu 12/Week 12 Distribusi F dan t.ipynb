# %% [markdown]
# # Distribusi F

# %%
from scipy.stats import f
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Misalkan 𝑣_1  = 20, 𝑣_2=15 dan 𝛼 =0,05. Dari tabel didapat nilai 𝐹=2,33. Sehingga :
# ![image.png](attachment:image.png)

# %%
v1, v2 = 20, 15
mean, var, skew, kurt = f.stats(v1, v2, moments='mvsk')

# %%
#Display the probability density function (pdf)
fig, ax = plt.subplots(1, 1)
x = np.linspace(f.ppf(0.01, v1, v2),
                f.ppf(0.99, v1, v2), 100)
ax.plot(x, f.pdf(x, v1, v2),
       'r-', lw=5, alpha=0.6, label='f pdf')

# %%
#Alternatively, the distribution object can be called (as a function) to fix the shape, location and scale parameters. 
#This returns a “frozen” RV object holding the given parameters fixed.
#Freeze the distribution and display the frozen pdf:
fig, ax = plt.subplots(1, 1)
rv = f(v1, v2)
ax.plot(x, rv.pdf(x), 'k-', lw=2, label='frozen pdf')

# %%
#Check accuracy of Cumulative distribution function (cdf) and Percent point function (ppf)(inverse of cdf — percentiles)
vals = f.ppf([0.001, 0.5, 0.999], v1, v2)
np.allclose([0.001, 0.5, 0.999], f.cdf(vals, v1, v2))
# Out:
# True

# %%
r = f.rvs(20, 15, size=1000)

# %%
fig, ax = plt.subplots(1, 1)
x = np.linspace(f.ppf(0.01, v1, v2),
                f.ppf(0.99, v1, v2), 100)
ax.plot(x, f.pdf(x, v1, v2),
       'r-', lw=5, alpha=0.6, label='f pdf')
ax.plot(x, rv.pdf(x), 'k-', lw=2, label='frozen pdf')
ax.hist(r, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()

# %% [markdown]
# # Distribusi t

# %%
from scipy.stats import t

# %% [markdown]
# 𝜈 =15, 𝑡_0,05  = 1,753 dan 𝑡_0,025  =2,131.
# ![image.png](attachment:image.png)

# %%
df = 15 #atau v
mean, var, skew, kurt = t.stats(df, moments='mvsk')

# %%
#Display the probability density function (pdf):
fig, ax = plt.subplots(1, 1)
x = np.linspace(t.ppf(0.01, df),
                t.ppf(0.99, df), 100)
ax.plot(x, t.pdf(x, df),
       'r-', lw=5, alpha=0.6, label='t pdf')

# %%
#frozen pdf
fig, ax = plt.subplots(1, 1)
rv = t(df)
ax.plot(x, rv.pdf(x), 'k-', lw=2, label='frozen pdf')

# %%
vals = t.ppf([0.001, 0.5, 0.999], df)
np.allclose([0.001, 0.5, 0.999], t.cdf(vals, df))
# Out:
# True

# %%
r = t.rvs(df, size=1000)

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(x, t.pdf(x, df),
       'r-', lw=5, alpha=0.6, label='t pdf')
ax.plot(x, rv.pdf(x), 'k-', lw=2, label='frozen pdf')
ax.hist(r, density=True, histtype='stepfilled', alpha=0.2)
ax.legend(loc='best', frameon=False)
plt.show()
